# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1, datetime.date(2018, 11, 29), '73', 'paid', None, None, '954', 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (2, datetime.date(2018, 11, 29), '24', 'paid', None, None, '984', 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (3, datetime.date(2018, 11, 29), '24', 'paid', None, None, '984', 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (4, datetime.date(2018, 11, 29), '73', 'paid', None, None, '954', 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
# ...

# %%
# %sql SELECT * FROM songplays WHERE song_id is not null or  artist_id is not null;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(6649, datetime.date(2018, 11, 21), '15', 'paid', 'SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4', '818', 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')]

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('10', 'Sylvie', 'Cruz', 'F', 'free'),
#  ('79', 'James', 'Martin', 'M', 'free'),
#  ('78', 'Chloe', 'Roth', 'F', 'free'),
#  ('26', 'Ryan', 'Smith', 'M', 'free'),
#  ('14', 'Theodore', 'Harris', 'M', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', '0', 115),
#  ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', '0', 268),
#  ('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', '1969', 148),
#  ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', '1984', 270),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', '0', 266)]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', 'NaN', 'NaN'),
#  ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', 'NaN', 'NaN'),
#  ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', '35.14968', '-90.04892'),
#  ('AR8ZCNI1187B9A069B', 'Planet P Project', '', 'NaN', 'NaN'),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', 'NaN', 'NaN')]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 29, 0, 0, 57, 796000), '0', '29', '48', '11', '2018', '3'),
#  (datetime.datetime(2018, 11, 29, 0, 1, 30, 796000), '0', '29', '48', '11', '2018', '3'),
#  (datetime.datetime(2018, 11, 29, 0, 4, 1, 796000), '0', '29', '48', '11', '2018', '3'),
#  (datetime.datetime(2018, 11, 29, 0, 4, 55, 796000), '0', '29', '48', '11', '2018', '3'),
#  (datetime.datetime(2018, 11, 29, 0, 7, 13, 796000), '0', '29', '48', '11', '2018', '3')]

# %%
# %sql SELECT songs.song_id, artists.artist_id From songs, artists WHERE songs.artist_id = artists.artist_id
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [('SOMJBYD12A6D4F8557', 'ARD0S291187B9B7BF5'),
#  ('SOYMRWW12A6D4FAB14', 'ARKFYS91187B98E58F'),
#  ('SOCIWDW12A8C13D406', 'ARMJAGH1187FB546F3'),
#  ('SOIAZJW12AB01853F1', 'AR8ZCNI1187B9A069B'),
#  ('SOUDSGM12AC9618304', 'ARNTLGG11E2835DDB9'),
#  ('SOQHXMF12AB0182363', 'ARGSJW91187B9B1D6B'),
#  ('SOXVLOJ12AB0189215', 'ARKRRTF1187B9984DA'),
#  ('SOHKNRJ12A6701D1F8', 'AR10USD1187B99F3F1'),
#  ('SONHOTT12A8C13493C', 'AR7G5I41187FB4CE6C'),
#  ('SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1'),
#  ('SOFSOCN12A8C143F5D', 'ARXR32B1187FB57099'),
#  ('SOBEBDG12A58A76D60', 'ARI3BMM1187FB4255E'),
#  ('SOILPQQ12AB017E82A', 'AR1ZHYZ1187FB3C717'),
#  ('SOHUOAP12A8AE488E9', 'ARD842G1187B997376'),
#  ('SOMUYGI12AB0188633', 'ARL7K851187B99ACD2'),
#  ('SOZVMJI12AB01808AF', 'ARNPAGP1241B9C7FD4'),
#  ('SOBONFF12A6D4F84D8', 'ARIK43K1187B9AE54C'),
#  ('SORAMLE12AB017C8B0', 'ARHHO3O1187B989413'),
# ...

# %%
# %sql SELECT song_id, artists.artist_id, artists.name  FROM songs JOIN artists ON songs.artist_id = artists.artist_id WHERE songs.title = 'Keepin It Real (Skit)' AND artists.name = 'Rated R' AND songs.duration = 115;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('SOMJBYD12A6D4F8557', 'ARD0S291187B9B7BF5', 'Rated R')]

# %%
# %sql SELECT * From songplays
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 6820 rows affected.
# [(1, datetime.date(2018, 11, 29), '73', 'paid', None, None, '954', 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (2, datetime.date(2018, 11, 29), '24', 'paid', None, None, '984', 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (3, datetime.date(2018, 11, 29), '24', 'paid', None, None, '984', 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (4, datetime.date(2018, 11, 29), '73', 'paid', None, None, '954', 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
# ...

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql select count(*) from time;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(6813,)]

# %%
# %sql select count(*) from artists;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(69,)]

# %%
# %sql select count(*) from songs;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(71,)]

# %%
# %sql select count(*) from users;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(96,)]

# %%
# %sql select count(*) from songplays;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(6820,)]
